# %%
# %run /Workspace/Users/vimal.s@diggibyte.com/utils_notebook

# %% [markdown]
# # Create DataFrames

# %%
purchase_df = create_purchase_df()

product_df = create_product_df()

# %%
purchase_df.display()

# %%
product_df.display()

# %%
print("Customers who bought only iphone13")

customers_only_iphone13(
    purchase_df
).display()

# %%
print("Customers who upgraded from iphone13 to iphone14")

upgraded_customers(
    purchase_df
).display()

# %%
print("Customers who bought all products")

customers_all_products(
    purchase_df,
    product_df
).display()
